# %% [markdown]
# # Classes

# %%
class Vehicle(object):
    wheels=0
    
    def __init__(self,wheels,maxSpeed=0):
        self.wheels=wheels
        self.maxSpeed=maxSpeed
        
    def fasterThan(self,otherVehicle):
        return self.maxSpeed > otherVehicle.maxSpeed

# %%
v1=Vehicle(2)
print(v1.maxSpeed)

# %%
class Bike(Vehicle):
  def __init__(self,maxSpeed=0):
    self.wheels=2
    self.maxSpeed=maxSpeed


b1=Bike(30)
b1.wheels
b1.maxSpeed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3d12111a806b> in <module>
# ----> 1 class Bike(Vehicle):
#       2   def __init__(self,maxSpeed=0):
#       3     self.wheels=2
#       4     self.maxSpeed=maxSpeed
#       5
#
# NameError: name 'Vehicle' is not defined

# %%
b2=Vehicle(4,80)

b1.fasterThan(b2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b26e2a551e8> in <module>
# ----> 1 b2=Vehicle(4,80)
#       2
#       3 b1.fasterThan(b2)
#
# NameError: name 'Vehicle' is not defined

# %%
# %load_ext autoreload
# %autoreload 2

from books import Book

#import importlib
#importlib.reload(books)

b=Book("The Hobbit","Tolkien")
print(b)
# Out:
# Book: The Hobbit by Tolkien
