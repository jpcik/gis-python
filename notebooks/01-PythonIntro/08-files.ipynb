# %% [markdown]
# ## Files

# %%
f = open('test.txt')

# %%
f = open('test.txt','w')
f.write('un autre texte')

# %%
f.close()

# %%
f = open ('cantons.txt','r')
f.read()

# %%
with open('cantons.txt','r') as f:
    f.read()

# %%
f.closed

# %%
f.read()

# %%
f = open ('cantons.txt','r')
f.readline()

# %%
f.seek(12)

# %%
f.readline()

# %%
f.seek(0)
entries = f.readlines()
entries

# %%
f.seek(0)
for line in f:
    print(line)

# %%
f.seek(0)
for line in f:
    data=line.strip().split(',')
    print(data)
