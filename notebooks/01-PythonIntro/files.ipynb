# %% [markdown]
# ## Files

# %%
f = open('test.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-9426bf859622> in <module>
# ----> 1 f = open('test.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
f = open('test.txt','w')
f.write('adding some text')

# %%
f.close()

# %%
f = open ('cantons.txt','r')
f.read()
# Out:
# 'Vaud,VD,100\nValais,VS,30\nJura,JU,5\nBern,BE,50\nGenève,GE,76\nFribourg,FR,24'

# %%
with open('cantons.txt','r') as f:
    f.read()

# %%
f.closed
# Out:
# True

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-571e9fb02258> in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open ('cantons.txt','r')
f.readline()
# Out:
# 'Vaud,VD,100\n'

# %%
f.seek(12)
# Out:
# 12

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
entries = f.readlines()
entries
# Out:
# ['Vaud,VD,100\n',
#  'Valais,VS,30\n',
#  'Jura,JU,5\n',
#  'Bern,BE,50\n',
#  'Genève,GE,76\n',
#  'Fribourg,FR,24']

# %%
f.seek(0)
for line in f:
    print(line)
# Out:
# Vaud,VD,100
#
# Valais,VS,30
#
# Jura,JU,5
#
# Bern,BE,50
#
# Genève,GE,76
#
# Fribourg,FR,24

# %%
f.seek(0)
for line in f:
    data=line.strip().split(',')
    print(data)
# Out:
# ['Vaud', 'VD', '100']
# ['Valais', 'VS', '30']
# ['Jura', 'JU', '5']
# ['Bern', 'BE', '50']
# ['Genève', 'GE', '76']
# ['Fribourg', 'FR', '24']
