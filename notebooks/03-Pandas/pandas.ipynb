# %%
import pandas as pd
import numpy as np

s= pd.Series([4,5,np.nan,23,])
s
# Out:
# 0     4.0
# 1     5.0
# 2     NaN
# 3    23.0
# dtype: float64

# %%
df=pd.DataFrame({'temperature':s,'humidity':np.random.randn(4)})

# %%
df
# Out:
#    temperature  humidity
# 0          4.0  0.381528
# 1          5.0 -1.921917
# 2          NaN  1.274573
# 3         23.0 -0.255719

# %%
import pandas as pd
hospitalsFile = "../../data/health-valais/hospitals.csv"

hospitals=pd.read_csv(hospitalsFile,encoding='utf-8')

hospitals
# Out:
#     CLASSE                                ETABLISSEMENT  \
# 0        1       HVS - Hôpital psychiatrique de Malévoz
# 1        1                  HVS - Clinique de Saint-Amé
# 2        1                    HVS - Hôpital de Martigny
# 3        1                        HVS - Hôpital de Sion
# 4        1      HVS - Institut Central des Hôpitaux ICH
# 5        1                      HVS - Hôpital de Sierre
# 6        1   HVS - Centre Valaisan de Pneumologie (CVP)
# 7        1                      HVS - Hôpital de Brigue
# 8        1                       HVS - Hôpital de Vige
# 9        1                     HRC - Hôpital de Monthey
# 10       1                        HRC - Hôpital d'Aigle
# 11       1         HRC - Hôpital de Vevey la Providence
# 12       1                           Clinique de Valre
# 13       1                          Clinique CIC Valais
# 14       1                             Leukerbad Clinic
# 15       1                        Berner Klinik Montana
# 16       1                 Luzerner Höhenklinik Montana
# 17       1  Clinique romande de réadaptation (CRR SUVA)
# 18       1         HRC - Hôpital de Vevey le Samaritain
# 19       1                    HRC - Hôpital de Montreux
# 20       1          HVS - Psychiatriezentrum Oberwallis
# 21       1                HUG-Clinique de Crans-Montana
#
#                      Adresse  numero   npa          ville      telephone  \
# 0           Route de Morgins    10.0  1870        Monthey   0800 012 210
# 1             Vers Saint-Amé    10.0  1890     St-Maurice  027/604.66.55
# 2        Avenue de la Fusion    27.0  1920       Martigny  027/603.90.00
# 3   Avenue du Grand-Champsec    80.0  1951           Sion  027/603.40.00
# 4   Avenue du Grand-Champsec    86.0  1951           Sion  027/603.47.00
# 5             Rue St-Charles    14.0  3960         Sierre  027/603.70.00
# 6         Route de la Moubra    87.0  3963  Crans-Montana  027/603.80.00
# 7            Oberlandstrasse    14.0  3900           Brig  027/604.33.33
# 8          Pflanzettastrasse     8.0  3930           Visp  027/604.33.33
# 9           Route de Morgins    54.0  1870        Monthey  024/473.17.31
# 10     Chemin du Grand-Chne     NaN  1860          Aigle  024/468.86.88
# 11         Av. de la Prairie     3.0  1800          Vevey  021/977.55.55
# 12            Rue Pré-Fleuri    16.0  1950           Sion  027/327.10.10
# 13            Route du Léman    29.0  1907          Saxon  027/743.40.40
# 14      Willy-Spühlerstrasse     2.0  3954      Leukerbad  027/472.51.08
# 15   Impasse Palace Bellevue     1.0  3963  Crans-Montana  027/485.51.21
# 16          Rte de L'Astoria     2.0  3963  Crans-Montana  027/485.81.81
# 17     Avenue Grand-Champsec    90.0  1951           Sion  027/603.30.30
# 18      Boulevard Paderewski     3.0  1800          Vevey  021/923.40.00
# 19         Avenue de Belmont    25.0  1820       Montreuy  021/966.66.66
# 20           Oberlandstrasse    14.0  3900           Brig  027/604.33.33
# 21         Impasse Clairmont     2.0  3963  Crans-Montana  027/485.61.11
#
#                                         site_internet  RuleID RuleID_1  \
# 0                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 1                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 2                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 3                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 4                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 5                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 6                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 7   http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
# 8   http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
# 9                http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 10               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 11               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 12                       http://www.cliniquevalere.ch     NaN   Rule_1
# 13                           http://www.cic-valais.ch     NaN   Rule_1
# 14                      http://www.leukerbadclinic.ch     NaN   Rule_1
# 15                         http://www.bernerklinik.ch     NaN   Rule_1
# 16                                  http://www.lhm.ch     NaN   Rule_1
# 17                             http://www.crr-suva.ch     NaN   Rule_1
# 18               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 19               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 20  http://www.hopitalvs.ch/de/unsere-fachbereiche...     NaN   Rule_1
# 21                 http://www.hug-ge.ch/crans-montana     NaN   Rule_1
#
#    RuleID_2  beds
# 0    Rule_1    30
# 1    Rule_1    20
# 2    Rule_1    10
# 3    Rule_1    11
# 4    Rule_1    15
# 5    Rule_1    30
# 6    Rule_1    12
# 7    Rule_1    45
# 8    Rule_1    23
# 9    Rule_1    45
# 10   Rule_1    23
# 11   Rule_1    34
# 12   Rule_1    12
# 13   Rule_1    43
# 14   Rule_1    33
# 15   Rule_1    44
# 16   Rule_1    22
# 17   Rule_1    33
# 18   Rule_1    50
# 19   Rule_1    33
# 20   Rule_1    42
# 21   Rule_1    22

# %%
hospitals.head(3)
# Out:
#    CLASSE                           ETABLISSEMENT              Adresse  \
# 0       1  HVS - Hôpital psychiatrique de Malévoz     Route de Morgins
# 1       1             HVS - Clinique de Saint-Amé       Vers Saint-Amé
# 2       1               HVS - Hôpital de Martigny  Avenue de la Fusion
#
#    numero   npa       ville      telephone                  site_internet  \
# 0    10.0  1870     Monthey   0800 012 210  http://www.hopitalduvalais.ch
# 1    10.0  1890  St-Maurice  027/604.66.55  http://www.hopitalduvalais.ch
# 2    27.0  1920    Martigny  027/603.90.00  http://www.hopitalduvalais.ch
#
#    RuleID RuleID_1 RuleID_2  beds
# 0     NaN   Rule_1   Rule_1    30
# 1     NaN   Rule_1   Rule_1    20
# 2     NaN   Rule_1   Rule_1    10

# %%
hospitals.columns
# Out:
# Index(['CLASSE', 'ETABLISSEMENT', 'Adresse', 'numero', 'npa', 'ville',
#        'telephone', 'site_internet', 'RuleID', 'RuleID_1', 'RuleID_2', 'beds'],
#       dtype='object')

# %%
hospitals.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
len(hospitals)
# Out:
# 22

# %%
hospitals.shape
# Out:
# (22, 12)

# %%
hospitals.dtypes
# Out:
# CLASSE             int64
# ETABLISSEMENT     object
# Adresse           object
# numero           float64
# npa                int64
# ville             object
# telephone         object
# site_internet     object
# RuleID           float64
# RuleID_1          object
# RuleID_2          object
# beds               int64
# dtype: object

# %%
hospitals['Adresse']
# Out:
# 0             Route de Morgins
# 1               Vers Saint-Amé
# 2          Avenue de la Fusion
# 3     Avenue du Grand-Champsec
# 4     Avenue du Grand-Champsec
# 5               Rue St-Charles
# 6           Route de la Moubra
# 7              Oberlandstrasse
# 8            Pflanzettastrasse
# 9             Route de Morgins
# 10       Chemin du Grand-Chne
# 11           Av. de la Prairie
# 12              Rue Pré-Fleuri
# 13              Route du Léman
# 14        Willy-Spühlerstrasse
# 15     Impasse Palace Bellevue
# 16            Rte de L'Astoria
# 17       Avenue Grand-Champsec
# 18        Boulevard Paderewski
# 19           Avenue de Belmont
# 20             Oberlandstrasse
# 21           Impasse Clairmont
# Name: Adresse, dtype: object

# %%
hospitals['beds'].mean()
# Out:
# 28.727272727272727

# %%
hospitals['beds'].max()
# Out:
# 50

# %%
hospitals.describe()
# Out:
#        CLASSE     numero          npa  RuleID       beds
# count    22.0  21.000000    22.000000     0.0  22.000000
# mean      1.0  27.476190  2728.909091     NaN  28.727273
# std       0.0  31.512885  1035.833178     NaN  12.585637
# min       1.0   1.000000  1800.000000     NaN  10.000000
# 25%       1.0   3.000000  1875.000000     NaN  20.500000
# 50%       1.0  14.000000  1951.000000     NaN  30.000000
# 75%       1.0  29.000000  3948.000000     NaN  40.000000
# max       1.0  90.000000  3963.000000     NaN  50.000000

# %%
aList=[4,6,2,1,6]
aSeries=pd.Series(aList)
aSeries
# Out:
# 0    4
# 1    6
# 2    2
# 3    1
# 4    6
# dtype: int64

# %%
aDataFrame=pd.DataFrame(aSeries)
aDataFrame.columns=["colName"]
aDataFrame
# Out:
#    colName
# 0        4
# 1        6
# 2        2
# 3        1
# 4        6

# %%
hospitals['newBeds']=0
hospitals
# Out:
#     CLASSE                                ETABLISSEMENT  \
# 0        1       HVS - Hôpital psychiatrique de Malévoz
# 1        1                  HVS - Clinique de Saint-Amé
# 2        1                    HVS - Hôpital de Martigny
# 3        1                        HVS - Hôpital de Sion
# 4        1      HVS - Institut Central des Hôpitaux ICH
# 5        1                      HVS - Hôpital de Sierre
# 6        1   HVS - Centre Valaisan de Pneumologie (CVP)
# 7        1                      HVS - Hôpital de Brigue
# 8        1                       HVS - Hôpital de Vige
# 9        1                     HRC - Hôpital de Monthey
# 10       1                        HRC - Hôpital d'Aigle
# 11       1         HRC - Hôpital de Vevey la Providence
# 12       1                           Clinique de Valre
# 13       1                          Clinique CIC Valais
# 14       1                             Leukerbad Clinic
# 15       1                        Berner Klinik Montana
# 16       1                 Luzerner Höhenklinik Montana
# 17       1  Clinique romande de réadaptation (CRR SUVA)
# 18       1         HRC - Hôpital de Vevey le Samaritain
# 19       1                    HRC - Hôpital de Montreux
# 20       1          HVS - Psychiatriezentrum Oberwallis
# 21       1                HUG-Clinique de Crans-Montana
#
#                      Adresse  numero   npa          ville      telephone  \
# 0           Route de Morgins    10.0  1870        Monthey   0800 012 210
# 1             Vers Saint-Amé    10.0  1890     St-Maurice  027/604.66.55
# 2        Avenue de la Fusion    27.0  1920       Martigny  027/603.90.00
# 3   Avenue du Grand-Champsec    80.0  1951           Sion  027/603.40.00
# 4   Avenue du Grand-Champsec    86.0  1951           Sion  027/603.47.00
# 5             Rue St-Charles    14.0  3960         Sierre  027/603.70.00
# 6         Route de la Moubra    87.0  3963  Crans-Montana  027/603.80.00
# 7            Oberlandstrasse    14.0  3900           Brig  027/604.33.33
# 8          Pflanzettastrasse     8.0  3930           Visp  027/604.33.33
# 9           Route de Morgins    54.0  1870        Monthey  024/473.17.31
# 10     Chemin du Grand-Chne     NaN  1860          Aigle  024/468.86.88
# 11         Av. de la Prairie     3.0  1800          Vevey  021/977.55.55
# 12            Rue Pré-Fleuri    16.0  1950           Sion  027/327.10.10
# 13            Route du Léman    29.0  1907          Saxon  027/743.40.40
# 14      Willy-Spühlerstrasse     2.0  3954      Leukerbad  027/472.51.08
# 15   Impasse Palace Bellevue     1.0  3963  Crans-Montana  027/485.51.21
# 16          Rte de L'Astoria     2.0  3963  Crans-Montana  027/485.81.81
# 17     Avenue Grand-Champsec    90.0  1951           Sion  027/603.30.30
# 18      Boulevard Paderewski     3.0  1800          Vevey  021/923.40.00
# 19         Avenue de Belmont    25.0  1820       Montreuy  021/966.66.66
# 20           Oberlandstrasse    14.0  3900           Brig  027/604.33.33
# 21         Impasse Clairmont     2.0  3963  Crans-Montana  027/485.61.11
#
#                                         site_internet  RuleID RuleID_1  \
# 0                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 1                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 2                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 3                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 4                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 5                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 6                       http://www.hopitalduvalais.ch     NaN   Rule_1
# 7   http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
# 8   http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
# 9                http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 10               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 11               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 12                       http://www.cliniquevalere.ch     NaN   Rule_1
# 13                           http://www.cic-valais.ch     NaN   Rule_1
# 14                      http://www.leukerbadclinic.ch     NaN   Rule_1
# 15                         http://www.bernerklinik.ch     NaN   Rule_1
# 16                                  http://www.lhm.ch     NaN   Rule_1
# 17                             http://www.crr-suva.ch     NaN   Rule_1
# 18               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 19               http://www.hopitalrivierachablais.ch     NaN   Rule_1
# 20  http://www.hopitalvs.ch/de/unsere-fachbereiche...     NaN   Rule_1
# 21                 http://www.hug-ge.ch/crans-montana     NaN   Rule_1
#
#    RuleID_2  beds  newBeds
# 0    Rule_1    30        0
# 1    Rule_1    20        0
# 2    Rule_1    10        0
# 3    Rule_1    11        0
# 4    Rule_1    15        0
# 5    Rule_1    30        0
# 6    Rule_1    12        0
# 7    Rule_1    45        0
# 8    Rule_1    23        0
# 9    Rule_1    45        0
# 10   Rule_1    23        0
# 11   Rule_1    34        0
# 12   Rule_1    12        0
# 13   Rule_1    43        0
# 14   Rule_1    33        0
# 15   Rule_1    44        0
# 16   Rule_1    22        0
# 17   Rule_1    33        0
# 18   Rule_1    50        0
# 19   Rule_1    33        0
# 20   Rule_1    42        0
# 21   Rule_1    22        0

# %%
hospitals['newBeds']=hospitals['beds']*2
hospitals.head()
# Out:
#    CLASSE                            ETABLISSEMENT                   Adresse  \
# 0       1   HVS - Hôpital psychiatrique de Malévoz          Route de Morgins
# 1       1              HVS - Clinique de Saint-Amé            Vers Saint-Amé
# 2       1                HVS - Hôpital de Martigny       Avenue de la Fusion
# 3       1                    HVS - Hôpital de Sion  Avenue du Grand-Champsec
# 4       1  HVS - Institut Central des Hôpitaux ICH  Avenue du Grand-Champsec
#
#    numero   npa       ville      telephone                  site_internet  \
# 0    10.0  1870     Monthey   0800 012 210  http://www.hopitalduvalais.ch
# 1    10.0  1890  St-Maurice  027/604.66.55  http://www.hopitalduvalais.ch
# 2    27.0  1920    Martigny  027/603.90.00  http://www.hopitalduvalais.ch
# 3    80.0  1951        Sion  027/603.40.00  http://www.hopitalduvalais.ch
# 4    86.0  1951        Sion  027/603.47.00  http://www.hopitalduvalais.ch
#
#    RuleID RuleID_1 RuleID_2  beds  newBeds
# 0     NaN   Rule_1   Rule_1    30       60
# 1     NaN   Rule_1   Rule_1    20       40
# 2     NaN   Rule_1   Rule_1    10       20
# 3     NaN   Rule_1   Rule_1    11       22
# 4     NaN   Rule_1   Rule_1    15       30

# %%
hospitals[5:8]
# Out:
#    CLASSE                               ETABLISSEMENT             Adresse  \
# 5       1                     HVS - Hôpital de Sierre      Rue St-Charles
# 6       1  HVS - Centre Valaisan de Pneumologie (CVP)  Route de la Moubra
# 7       1                     HVS - Hôpital de Brigue     Oberlandstrasse
#
#    numero   npa          ville      telephone  \
# 5    14.0  3960         Sierre  027/603.70.00
# 6    87.0  3963  Crans-Montana  027/603.80.00
# 7    14.0  3900           Brig  027/604.33.33
#
#                                        site_internet  RuleID RuleID_1  \
# 5                      http://www.hopitalduvalais.ch     NaN   Rule_1
# 6                      http://www.hopitalduvalais.ch     NaN   Rule_1
# 7  http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
#
#   RuleID_2  beds  newBeds
# 5   Rule_1    30       60
# 6   Rule_1    12       24
# 7   Rule_1    45       90

# %%
hospitals.loc[11]
# Out:
# CLASSE                                              1
# ETABLISSEMENT    HRC - Hôpital de Vevey la Providence
# Adresse                             Av. de la Prairie
# numero                                              3
# npa                                              1800
# ville                                           Vevey
# telephone                               021/977.55.55
# site_internet    http://www.hopitalrivierachablais.ch
# RuleID                                            NaN
# RuleID_1                                       Rule_1
# RuleID_2                                       Rule_1
# beds                                               34
# newBeds                                            68
# Name: 11, dtype: object

# %%
hospitals.loc[9:12, ['ETABLISSEMENT','beds']]
# Out:
#                            ETABLISSEMENT  beds
# 9               HRC - Hôpital de Monthey    45
# 10                 HRC - Hôpital d'Aigle    23
# 11  HRC - Hôpital de Vevey la Providence    34
# 12                    Clinique de Valre    12

# %%
hospitals.loc[(hospitals['Adresse'].str.startswith('Avenue')) & (hospitals['beds']<15)]
# Out:
#    CLASSE              ETABLISSEMENT                   Adresse  numero   npa  \
# 2       1  HVS - Hôpital de Martigny       Avenue de la Fusion    27.0  1920
# 3       1      HVS - Hôpital de Sion  Avenue du Grand-Champsec    80.0  1951
#
#       ville      telephone                  site_internet  RuleID RuleID_1  \
# 2  Martigny  027/603.90.00  http://www.hopitalduvalais.ch     NaN   Rule_1
# 3      Sion  027/603.40.00  http://www.hopitalduvalais.ch     NaN   Rule_1
#
#   RuleID_2  beds  newBeds
# 2   Rule_1    10       20
# 3   Rule_1    11       22

# %%
hospitals.sort_values(by='npa',ascending=False).head()
# Out:
#     CLASSE                               ETABLISSEMENT  \
# 21       1               HUG-Clinique de Crans-Montana
# 16       1                Luzerner Höhenklinik Montana
# 6        1  HVS - Centre Valaisan de Pneumologie (CVP)
# 15       1                       Berner Klinik Montana
# 5        1                     HVS - Hôpital de Sierre
#
#                     Adresse  numero   npa          ville      telephone  \
# 21        Impasse Clairmont     2.0  3963  Crans-Montana  027/485.61.11
# 16         Rte de L'Astoria     2.0  3963  Crans-Montana  027/485.81.81
# 6        Route de la Moubra    87.0  3963  Crans-Montana  027/603.80.00
# 15  Impasse Palace Bellevue     1.0  3963  Crans-Montana  027/485.51.21
# 5            Rue St-Charles    14.0  3960         Sierre  027/603.70.00
#
#                          site_internet  RuleID RuleID_1 RuleID_2  beds  \
# 21  http://www.hug-ge.ch/crans-montana     NaN   Rule_1   Rule_1    22
# 16                   http://www.lhm.ch     NaN   Rule_1   Rule_1    22
# 6        http://www.hopitalduvalais.ch     NaN   Rule_1   Rule_1    12
# 15          http://www.bernerklinik.ch     NaN   Rule_1   Rule_1    44
# 5        http://www.hopitalduvalais.ch     NaN   Rule_1   Rule_1    30
#
#     newBeds
# 21       44
# 16       44
# 6        24
# 15       88
# 5        60

# %%
hospitals['ville'].unique()
# Out:
# array(['Monthey', 'St-Maurice', 'Martigny', 'Sion', 'Sierre',
#        'Crans-Montana', 'Brig', 'Visp', 'Aigle', 'Vevey', 'Saxon',
#        'Leukerbad', 'Montreuy'], dtype=object)

# %%
hospitalsModif=hospitals.loc[:,['ETABLISSEMENT','newBeds','ville']]
hospitalsModif.to_csv('hospitals_modif.csv',sep=',',encoding='utf-8')

# %%
for idx,row in hospitals.iterrows():
    print(row['ville'])
    print(idx)
# Out:
# Monthey
# 0
# St-Maurice
# 1
# Martigny
# 2
# Sion
# 3
# Sion
# 4
# Sierre
# 5
# Crans-Montana
# 6
# Brig
# 7
# Visp
# 8
# Monthey
# 9
# Aigle
# 10
# Vevey
# 11
# Sion
# 12
# Saxon
# 13
# Leukerbad
# 14
# Crans-Montana
# 15
# Crans-Montana
# 16
# Sion
# 17
# Vevey
# 18
# Montreuy
# 19
# Brig
# 20
# Crans-Montana
# 21

# %%
groups=hospitals.groupby('ville')
groups.get_group('Brig')
# Out:
#     CLASSE                        ETABLISSEMENT          Adresse  numero  \
# 7        1              HVS - Hôpital de Brigue  Oberlandstrasse    14.0
# 20       1  HVS - Psychiatriezentrum Oberwallis  Oberlandstrasse    14.0
#
#      npa ville      telephone  \
# 7   3900  Brig  027/604.33.33
# 20  3900  Brig  027/604.33.33
#
#                                         site_internet  RuleID RuleID_1  \
# 7   http://www.spitalvs.ch/de/spital-wallis/stando...     NaN   Rule_1
# 20  http://www.hopitalvs.ch/de/unsere-fachbereiche...     NaN   Rule_1
#
#    RuleID_2  beds  newBeds
# 7    Rule_1    45       90
# 20   Rule_1    42       84
