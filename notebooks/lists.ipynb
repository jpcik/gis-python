# %% [markdown]
# # Lists
# ## Basic lists

# %%
[3,4,6,2,1]
# Out:
# [3, 4, 6, 2, 1]

# %%
[[2,3],[5,6],[4,3]]

# %%
list=[3,4.5,6,2,2.1]
len(list)

# %%
list[2]

# %% [markdown]
# The negative index -1 gives the last item. Negative indexes go backwards.

# %%
list[-1]

# %%
type(list[1])

# %% [markdown]
# ## List operations

# %% [markdown]
# Delete an item

# %%
del list[2]
print(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-c7ce496d0e02> in <module>
# ----> 1 del list[2]
#       2 print(list)
#
# TypeError: 'type' object does not support item deletion

# %% [markdown]
# Append an item to the list

# %%
list.append(44)
print(list)

# %%
list.reverse()
print(list)

# %%
list.sort()
print(list)

# %% [markdown]
# Replace a value in the list

# %%
list[0]=55
print(list)
